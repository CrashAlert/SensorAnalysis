# %% [markdown]
# ## Sensor Analysis Notebook
# Reads all csvs from the data directory and can plot the data as well as add information to it such as acceleration based on gyro or gps data.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import ipywidgets as widgets

from dataSpec import sensor_dict
from plots import fun_dict

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')
matplotlib.style.use('seaborn-notebook')
plt.rcParams['figure.figsize'] = (14.0, 11.0)

# %% [markdown]
# #### Choose the file to work with

# %%
from os import listdir
from os.path import join, isfile
from IPython.display import display
p = 'data'
w = widgets.Dropdown(
    options=[f for f in listdir(p) if isfile(join(p, f))],
    description='File:',
)
display(w)

# %%
file = join(p, w.value)
data = pd.read_csv(file)

# %% [markdown]
# #### Choose function to plot and interval

# %%
fun = widgets.Dropdown(
    options=list(fun_dict.keys()),
    description='Plot:',
)
display(fun)

# %%
fun_dict[fun.value](data, plt)
